# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
nf1_data = pd.read_csv('NFL Play by Play 2009-2017 (v4).csv',low_memory = False)
sf_permits = pd.read_csv('Building_Permits.csv',low_memory = False)
np.random.seed(0)

# %%
nf1_data.sample(5)
# Out:
#               Date      GameID  Drive  qtr  down   time  TimeUnder  TimeSecs  \
# 244485  2014-10-26  2014102607     18    3   1.0  00:39          1     939.0
# 115340  2011-11-20  2011112000     22    4   1.0  06:47          7     407.0
# 68357   2010-11-14  2010111401      8    2   NaN  00:23          1    1823.0
# 368377  2017-09-24  2017092405     24    4   1.0  08:48          9     528.0
# 384684  2017-11-05  2017110505     11    2   1.0  09:15         10    2355.0
#
#         PlayTimeDiff SideofField  ...    yacEPA  Home_WP_pre  Away_WP_pre  \
# 244485          12.0          TB  ...  1.240299     0.225647     0.774353
# 115340          44.0         OAK  ...       NaN     0.056036     0.943964
# 68357            0.0         CLE  ...       NaN     0.365307     0.634693
# 368377           8.0         CLE  ...  1.075660     0.935995     0.064005
# 384684           0.0         DEN  ...       NaN     0.928474     0.071526
#
# ...

# %%
sf_permits.sample(5)
# Out:
#        Permit Number  Permit Type  Permit Type Definition  \
# 78651   201503120624            8  otc alterations permit
# 177779  201707071220            8  otc alterations permit
# 64978        M529127            8  otc alterations permit
# 165958  201704073507            8  otc alterations permit
# 147902  201701237639            8  otc alterations permit
#
#        Permit Creation Date Block   Lot  Street Number Street Number Suffix  \
# 78651            03/12/2015  4273   029           2986                  NaN
# 177779           07/07/2017  0453  004A            950                  NaN
# 64978            10/21/2014  0478   011           1290                  NaN
# 165958           04/07/2017  6507  003A           1134                  NaN
# 147902           01/23/2017  0623   001           1755                  NaN
#
#        Street Name Street Suffix  ...  Existing Construction Type  \
# 78651         26th            St  ...                         5.0
# ...

# %% [markdown]
# how many missing data points we have

# %%
missing_values_count = nf1_data.isnull().sum()
missing_values_count[0:10]
# Out:
# Date                0
# GameID              0
# Drive               0
# qtr                 0
# down            61154
# time              224
# TimeUnder           0
# TimeSecs          224
# PlayTimeDiff      444
# SideofField       528
# dtype: int64

# %% [markdown]
# how many total missing values do we have?

# %%
total_cells = np.product(nf1_data.shape)
total_missing = missing_values_count.sum()
#percentage of missing values
(total_missing / total_cells)*100
# Out:
# 27.66722370547874

# %%
total_cells = np.product(sf_permits.shape)
total_missing = missing_values_count.sum()
# percentage of missing values
(total_missing / total_cells)*100
# Out:
# 134.52111029265612

# %%
nf1_data.shape
# Out:
# (407688, 102)

# %%
sf_permits.shape
# Out:
# (198900, 43)

# %%
# Remove all the rows that contain missing values
nf1_data.dropna()
# Out:
# Empty DataFrame
# ...

# %%
# remove all columns with at least one missing values
columns_with_na_dropped = nf1_data.dropna(axis=1)
columns_with_na_dropped.head()
# Out:
#          Date      GameID  Drive  qtr  TimeUnder  ydstogo  ydsnet  \
# 0  2009-09-10  2009091000      1    1         15        0       0
# 1  2009-09-10  2009091000      1    1         15       10       5
# 2  2009-09-10  2009091000      1    1         15        5       2
# 3  2009-09-10  2009091000      1    1         14        8       2
# 4  2009-09-10  2009091000      1    1         14        8       2
#
#    PlayAttempted  Yards.Gained  sp  ...  AwayTeam  Timeout_Indicator  \
# 0              1            39   0  ...       TEN                  0
# 1              1             5   0  ...       TEN                  0
# 2              1            -3   0  ...       TEN                  0
# 3              1             0   0  ...       TEN                  0
# 4              1             0   0  ...       TEN                  0
#
#    posteam_timeouts_pre HomeTimeouts_Remaining_Pre  \
# 0                     3                          3
# ...

# %%
# how much data we lose?
print("Column with original dataset: %d \n"% nf1_data.shape[1])
print("Columns_with_na_dropped : %d"% columns_with_na_dropped.shape[1])
# Out:
# Column with original dataset: 102
#
# Columns_with_na_dropped : 37

# %%
# we lost quite a bit of data at this point but at this point we have sucessfully removed all NaN from our data

# %%
# row from sf_permit dataset remove all missing values
rows_with_na_dropped = sf_permits.dropna(axis = 1)
rows_with_na_dropped.head()
# Out:
#   Permit Number  Permit Type            Permit Type Definition  \
# 0  201505065519            4                      sign - erect
# 1  201604195146            4                      sign - erect
# 2  201605278609            3  additions alterations or repairs
# 3  201611072166            8            otc alterations permit
# 4  201611283529            6                       demolitions
#
#   Permit Creation Date Block  Lot  Street Number Street Name Current Status  \
# 0           05/06/2015  0326  023            140       Ellis        expired
# 1           04/19/2016  0306  007            440       Geary         issued
# 2           05/27/2016  0595  203           1647     Pacific      withdrawn
# 3           11/07/2016  0156  011           1230     Pacific       complete
# 4           11/28/2016  0342  001            950      Market         issued
#
#   Current Status Date  Filed Date      Record ID
# 0          12/21/2017  05/06/2015  1380611233945
# ...

# %%
columns_with_na_dropped = sf_permits.dropna(axis = 1)
columns_with_na_dropped

print("columns in original_dataset: %d \n" % sf_permits.shape[1])
print("Columns with na dropped : %d "% sf_permits.shape[1])
# Out:
# columns in original_dataset: 43
#
# Columns with na dropped : 43

# %% [markdown]
# ### Filling Missin Values Automatically

# %%
# Get small subset of NFL Dataset
subset_Nf1_data = nf1_data.loc[:,'EPA':'Season'].head()
subset_Nf1_data
# Out:
#         EPA    airEPA    yacEPA  Home_WP_pre  Away_WP_pre  Home_WP_post  \
# 0  2.014474       NaN       NaN     0.485675     0.514325      0.546433
# 1  0.077907 -1.068169  1.146076     0.546433     0.453567      0.551088
# 2 -1.402760       NaN       NaN     0.551088     0.448912      0.510793
# 3 -1.712583  3.318841 -5.031425     0.510793     0.489207      0.461217
# 4  2.097796       NaN       NaN     0.461217     0.538783      0.558929
#
#    Away_WP_post  Win_Prob       WPA    airWPA    yacWPA  Season
# 0      0.453567  0.485675  0.060758       NaN       NaN    2009
# 1      0.448912  0.546433  0.004655 -0.032244  0.036899    2009
# 2      0.489207  0.551088 -0.040295       NaN       NaN    2009
# 3      0.538783  0.510793 -0.049576  0.106663 -0.156239    2009
# 4      0.441071  0.461217  0.097712       NaN       NaN    2009

# %%
# We can use pandas fillna() function to fill missing values
subset_Nf1_data.fillna(0)
# Out:
#         EPA    airEPA    yacEPA  Home_WP_pre  Away_WP_pre  Home_WP_post  \
# 0  2.014474  0.000000  0.000000     0.485675     0.514325      0.546433
# 1  0.077907 -1.068169  1.146076     0.546433     0.453567      0.551088
# 2 -1.402760  0.000000  0.000000     0.551088     0.448912      0.510793
# 3 -1.712583  3.318841 -5.031425     0.510793     0.489207      0.461217
# 4  2.097796  0.000000  0.000000     0.461217     0.538783      0.558929
#
#    Away_WP_post  Win_Prob       WPA    airWPA    yacWPA  Season
# 0      0.453567  0.485675  0.060758  0.000000  0.000000    2009
# 1      0.448912  0.546433  0.004655 -0.032244  0.036899    2009
# 2      0.489207  0.551088 -0.040295  0.000000  0.000000    2009
# 3      0.538783  0.510793 -0.049576  0.106663 -0.156239    2009
# 4      0.441071  0.461217  0.097712  0.000000  0.000000    2009

# %%
#replace all NA's the values that came directly after in it the same column,
#then replace all missing na's with 0 
subset_Nf1_data.fillna(method = 'bfill',axis = 0).fillna("0")
# Out:
# C:\Users\Dhanashri\AppData\Local\Temp\ipykernel_11920\259794668.py:3: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   subset_Nf1_data.fillna(method = 'bfill',axis = 0).fillna("0")
#         EPA    airEPA    yacEPA  Home_WP_pre  Away_WP_pre  Home_WP_post  \
# 0  2.014474 -1.068169  1.146076     0.485675     0.514325      0.546433
# 1  0.077907 -1.068169  1.146076     0.546433     0.453567      0.551088
# 2 -1.402760  3.318841 -5.031425     0.551088     0.448912      0.510793
# 3 -1.712583  3.318841 -5.031425     0.510793     0.489207      0.461217
# 4  2.097796         0         0     0.461217     0.538783      0.558929
#
#    Away_WP_post  Win_Prob       WPA    airWPA    yacWPA  Season
# 0      0.453567  0.485675  0.060758 -0.032244  0.036899    2009
# 1      0.448912  0.546433  0.004655 -0.032244  0.036899    2009
# 2      0.489207  0.551088 -0.040295  0.106663 -0.156239    2009
# ...

# %%
# Filling missing value is also known as imputation.

# %%
sf_permits.fillna(method = 'bfill',axis = 0).fillna('0')
# Out:
# C:\Users\Dhanashri\AppData\Local\Temp\ipykernel_11920\3882677362.py:1: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   sf_permits.fillna(method = 'bfill',axis = 0).fillna('0')
#        Permit Number  Permit Type            Permit Type Definition  \
# 0       201505065519            4                      sign - erect
# 1       201604195146            4                      sign - erect
# 2       201605278609            3  additions alterations or repairs
# 3       201611072166            8            otc alterations permit
# 4       201611283529            6                       demolitions
# ...              ...          ...                               ...
# 198895       M862628            8            otc alterations permit
# 198896  201712055595            8            otc alterations permit
# 198897       M863507            8            otc alterations permit
# ...
